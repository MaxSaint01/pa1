# %% [markdown]
# # Homework 1: Strings, Expressions and Arrays (50 points)
#
# Please complete this notebook by filling in the cells provided. The solved homework should be uploaded to Canvas.

# %% [markdown]
# #### Reading:
# - Textbook chapters  [3.1-3.3](http://www.inferentialthinking.com/chapters/03/programming-in-python.html) (Programming in Python),
# [4](https://www.inferentialthinking.com/chapters/04/Data_Types) (Data Types) and [5](https://www.inferentialthinking.com/chapters/05/Sequences.html) (Sequences).
#
# #### Deadline:
#
# This assignment is due on **Thursday of 2nd week, January 20 at 9:00am**. Late work will not be accepted unless you have made special arrangements with the instructor.
#
# Directly sharing answers is not okay, but discussing problems with the course staff is encouraged, and with other students is allowed.
#
# You should start early so that you have time to get help if you're stuck.

# %%
# Don't change this cell; just run it. 

import numpy as np
import pandas as pd
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## 1. Strings (9 points)

# %% [markdown]
# **Question 1.** Run the following cell. Before running try to guess the answer. Explain why the output of that command is the integer you obtain.

# %%
len('B. Sc.')

# %% [markdown]
# The ouput is 6.  This is because len measures the number of symbols between the single quote marks and there are 6 symbols total (3 letters, 2 dots and a space).

# %% [markdown]
# **Question 2.** Use the *replace* function for strings to change the string *'working hardly'* into the string *'hardly working'*. You must do everything into one line of code and you can only replace one full word with a different full word. An example of using *replace* twice in one line of code is below. [Note: the output should be a string of the same length as the one you started with; no extra spaces etc.]

# %%
# this cell illustrates the use of .replace twice.  Note these execute left to right.
'on campus'.replace('on','healthy').replace('campus','place')

# %%
# use this cell to answer the question
'working hardly'.replace('working', 'potato').replace('hardly', 'working').replace('potato', 'hardly')

# %% [markdown]
# **Question 3.**
# Recall how the *split* command breaks a string into a list a strings by a specified separator (run next cell for an example). Also recall how to slice a list (run the cell after). Use the split command, list slicing, and the string concatenation using + you can make new strings from pieces of old ones.

# %%
# this cell illustrates the use of the split command
mystring1 = 'There are three kinds of lies: lies, damned lies, and statistics.' 
mystring1.split(',')

# %%
# this cell illustrates the use of slicing.  This retrieves the second element after the split:
mystring1.split(',')[2]

# %% [markdown]
# Assign the value `There are three kinds of statistics.` to `mach2` using pieces of `mystring1` above by split, indexing, and concatenation.  **Hint: what should you split on?**

# %%
# use this cell to answer the question using `mystring1` 
mystring1.split()
a=mystring1.split()[0]
b=mystring1.split()[1]
c=mystring1.split()[2]
d=mystring1.split()[3]
e=mystring1.split()[4]
f=mystring1.split()[10]
mach2=a+" "+b+" "+c+" "+d+" "+e+" "+f

# %% [markdown]
# ## 2. Names and Assignment Statements (9 points)

# %% [markdown]
# **Question 1.** You are testing to see how python compares floats and ints.  Is 1.0 (a float) equal to 1 (an int)?  You run the following cell, Python produces a cryptic error message.

# %%
1.0 = 1

# %% [markdown]
# ## Choose the best explanation of what's wrong with the code, and then assign 1, 2, 3, or 4 to `Answer1` below to indicate your answer.
#
# 1. There is already a variable with the name 1.0.
#
# 2. `=` is the assignment operator, you should use the "test for equality" operator `==`
#
# 3. You can't compare `int`s and `float`s in python.
#
# 4. I don't get an error message. This is a trick question.

# %% [markdown]
# *Write your answer in this cell by replacing '?'.*
#
# Answer1 = 2

# %% [markdown]
# **Question 2.** When you run the following cell, Python will produce another cryptic error message.

# %%
four = 4
root_four = sqrt(four)

# %% [markdown]
# Choose the best explanation of what's wrong with the code and assign 1, 2, 3, or 4 to `Answer2` below to indicate your answer.
#
# 1. The `sqrt` operation only works on numeric data types, not variable names like `four`.
#
# 2. The name "root_four" is not a valid variable name.
#
# 3. `sqrt` requires a prior incantation of `from np import sqrt` or must be called as `np.sqrt`.
#
# 4. The `sqrt` function uses square brackets for its arguments `[]`

# %% [markdown]
# *Write your answer in this cell by replacing '?'.*
#
# Answer2 = 3

# %% [markdown]
# **Question 3. Check that you can use trig.**
# Evaluate the reciporical of the square root of two and the cosine of 45 degrees.  Show that they are, if not the same, pretty close.

# %%
one_over_root_two = 1/np.sqrt(2)
cosine_45 = np.cos(np.pi*45/180)
difference = one_over_root_two - cosine_45
print(difference)

# %% [markdown]
# | Lake Name | Elevation (ft) | Surface area (km$^2$) | latitude (deg) |
# | --- | :-: | :-: | :-: |
# | Erie | 571 | 25700 |  42.1  |
# | Huron | 577 | 60000 |  45.0 |
# | Michigan | 577 | 58000 | 43.4 |
# | Ontario | 246 | 19000 |  43.6 |
# | Superior | 600 | 82000 |  47.7 |

# %% [markdown]
# ## 3. Creating Arrays (15 points)
#
# **Question 1.** In the next cell, make a five-element array called `lakes` containing the names of the five Laurentian Great Lakes from the table above.

# %%
lakes = np.array(["Erie", "Huron", "Michigan", "Ontario", "Superior"])

# %% [markdown]
# **Question 2.** Make an string called `all_five` containing the five names from `lakes` joined by commas, e.g. `One,Two,Three,Four`.

# %%
all_five = lakes[0]+","+lakes[1]+","+lakes[2]+","+lakes[3]+","+lakes[4]

# %% [markdown]
# >"This panda walked into a tea shop and ordered a salad and ate it. Then it pulled out a pistol, shot the man at the next table dead, and walked out. Everyone rushed after it, shouting, 'Stop! Stop! Why did you do that?' 'Because I'm a panda,' said the panda. 'That's what pandas do. If you don't believe me, look in the dictionary.' So they looked in the dictionary and sure enough they found Panda: Raccoon-like animal of Asia. Eats shoots and leaves." —Ursula K. Le Guin, *Steering the Craft*, 1998

# %% [markdown]
# Strings have a method called `join`.  `join` takes one argument, an array of strings.  It returns a single string.  Specifically, the value of `a_string.join(an_array)` is a single string that's the [concatenation](https://en.wikipedia.org/wiki/Concatenation) ("putting together") of all the strings in `an_array`, **except** `a_string` is inserted in between each string.  That was hard to say.  Easy to demonstrate:

# %%
"*".join(["One", "Two", "Three", "Four", "Five"])

# %%
" AND ".join(["One", "Two", "Three", "Four", "Five"])  # Note "space-AND-space"

# %% [markdown]
# **Question 3.** Create an array `book_title_words` containing the words `Eats`, `Shoots`, and `and Leaves`.  Use and the method `join` to make two strings:
#
# 1. "Eats, Shoots, and Leaves" (call this one `with_commas`)
# 2. "Eats Shoots and Leaves" (call this one `without_commas`)

# %%
book_title_words = np.array(["Eats", "Shoots", "and Leaves"])
with_commas = ", ".join(book_title_words)
without_commas = " ".join(book_title_words)

# These lines are provided just to print out your answers.
print('with_commas:', with_commas)
print('without_commas:', without_commas)

# %% [markdown]
# ## 4.  Arrays Indexing and Arithmetic (9 points)
#
# These exercises give you practice accessing individual elements of arrays.  In Python (and in many programming languages), elements are accessed by *index*, so the first element is the element at index 0.
#
# **Question 1.** The cell below creates an array of some numbers, the elevations at low water of the Great Lakes in feet.  Set `lake_ontario_feet` to the fourth element of `lake_elevations`.  1 foot is exactly 0.3048 meters.   Set `lake_ontario_meters` to the elevation of Lake Ontario in meters.

# %%
lake_elevations = np.array([571, 577, 577, 246, 600])  # Note these are in alphabetical order, E H M O S 
# The fourth element is the elevation of Lake Ontario
lake_ontario_feet = lake_elevations[3]
lake_ontario_meters = lake_ontario_feet * 0.3048

# %% [markdown]
# **Question 2.**   Convert the array above to meters.

# %%
elevations_in_meters = lake_elevations * 0.3048
print(elevations_in_meters)

# %% [markdown]
# **Question 3.** Evaluate the cosines of the latitudes of the centers of the Great Lakes.  **Hint: this number is roughly proportional to the intensity of year-averaged sunlight relative to the equator.  Is this number increasing or decreasing with latitude?  Will it ever change sign?**  **Hint: you can do this with one step.**

# %%
lake_latitudes = np.array([42.1, 45.0, 43.4, 43.6, 47.7])
cosine_latitudes = np.cos(np.pi*lake_latitudes/180)
print(cosine_latitudes)

# %% [markdown]
# ## 5. Weather data (8 points)
#
# The cell below loads a datafile from the NOAA Centers for Environmental Information database, a list of the high and low temperatures for 2020 at midway airport.
# https://www.ncdc.noaa.gov/cdo-web/datasets/GHCND/stations/GHCND:USC00111577/detail
#
#
# In the next cell, you will read some data into  table called `timeseries`. You will learn about Tables in Week 2, but you do not need to worry about when solving this exercise

# %%
# read the data into a table
temptimeseries = pd.read_csv("Weather-MDW-2020.csv", delimiter=",")[["DATE", "TMIN", "PRCP"]]
# this shows the first 4 rows of the table
temptimeseries.head(4)

# %% [markdown]
# In the next cell, the name `tmin` is assigned to an **array** of population estimates.

# %%
tmin = temptimeseries.TMIN.values
tmin

# %% [markdown]
# In this question, you will apply some built-in Numpy functions to this array.
#
# <div>
# <img src="attachment:array_diff.png" width="600"/>
# </div>
#
#
# The difference function `np.diff` subtracts each element in an array by the element that preceeds it. As a result, the length of the array `np.diff` returns will always be one less than the length of the input array.
#
# <div>
# <img src="attachment:array_cumsum.png" width="600"/>
# </div>
#
#
# The cumulative sum function `np.cumsum` outputs an array of partial sums. For example, the third element in the output array corresponds to the sum of the first, second, and third elements.
#
# **Question 1.** Often we are interested understanding how values change with time. Use `np.diff` and `np.max` and `np.min`  to calculate the largest and smallest daily changes in minimum recorded temperature between consecutive (or at least adjacent) days.

# %%
# Answer here
test=np.diff(tmin)
largest_temp_change = np.max(np.abs(test))
smallest_temp_change = np.min(np.abs(test))

# %% [markdown]
# **Question 2.** Describe in words the result of the following expression. What do the values in the resulting array represent?

# %%
np.cumsum(temptimeseries.PRCP)

# %% [markdown]
# *Answer here:*
# The following expression uses the cumsum function to cumulatively add up all elements in the precipitation column so far, demonstrating how much total precipitation has fallen by a specific day.  For example, day 3 shows that a total of 0.01 inches of precipitation have fallen by the end of the 3rd day, while the last value (365) shows that a total of 36.46 inches of precipitation have fallen on the ground over the course of the past year.
